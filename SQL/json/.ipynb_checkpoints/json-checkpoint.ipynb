# %%
import sqlalchemy as sql
from sqlalchemy import create_engine
import psycopg2
import geopandas as gpd
import pandas as pd
import geoalchemy2
import sqlite3
import json
import shapely
# %matplotlib inline
import noise
import numpy as np
import matplotlib
from mpl_toolkits.mplot3d import axes3d

# %%
with open('SalidaFME1.json') as f:
    geojson = json.loads(f.read())

# %%
dfj = gpd.read_file('SalidaFME1.json')

# %%
dfj['point_id']= dfj.index
dfj
# Out:
#                                             alturas_ola longitud latitud  \
# 0     0.45341894,0.45281014,0.45453027,0.45678744,0....   -89.75   26.75
# 1     0.45436582,0.45006692,0.44814834,0.45168224,0....    -89.5   26.75
# 2     0.45334718,0.4474001,0.44745815,0.4538375,0.45...   -89.25   26.75
# 3     0.45480344,0.44959858,0.45220503,0.45509776,0....      -89   26.75
# 4     0.4608303,0.4565792,0.4570602,0.45764166,0.458...   -88.75   26.75
# ...                                                 ...      ...     ...
# 8353  0.24721572,0.25101197,0.26314446,0.28622887,0....   -56.25    7.25
# 8354  0.23778251,0.24563119,0.26780698,0.28860712,0....      -56    7.25
# 8355  0.2253547,0.24362324,0.2740655,0.2948075,0.316...   -55.75    7.25
# 8356  0.23020278,0.25435516,0.27737927,0.29132563,0....    -55.5    7.25
# 8357  0.21316274,0.23346135,0.24079537,0.24264361,0....   -55.25    7.25
#
#                         geometry  point_id
# 0     POINT (-89.75000 26.75000)         0
# ...

# %%
df = pd.DataFrame(columns=('id', 'fecha', 'altura_ola'))
for i in range(0,8358):
    temp=dfj.iloc[i, 0]
    separador = temp.split(',')
    temp=[float(x) for x in separador]
    dia1=sum(temp[0:24]) / len(temp[0:24])
    dia2=sum(temp[25:48]) / len(temp[25:48])
    dia3=sum(temp[49:72]) / len(temp[49:72])
    dia4=sum(temp[73:96]) / len(temp[73:96])
    dia5=sum(temp[97:120]) / len(temp[97:120])
    geom=dfj.iloc[i, 3]
    ids=i
    fechas=['2020-09-10 12:00:00','2020-09-11 12:00:00','2020-09-12 12:00:00','2020-09-13 12:00:00','2020-09-14 12:00:00']
    prom=[dia1,dia2,dia3,dia4,dia5]
    for j in range(0,5):
        index=len(df)
        df.loc[index]=[ids,fechas[j],prom[j]]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41790 entries, 0 to 41789
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          41790 non-null  object
#  1   fecha       41790 non-null  object
#  2   altura_ola  41790 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ MB

# %%
dfpuntos= dfj.iloc[:,[3,4]]
dfpuntos = dfpuntos.set_geometry('geometry')

# %%
temp=geojson['features'][0]['properties']['alturas_ola'] 
separador = temp.split(',')
# Out:
# ['0.45341894',
#  '0.45281014',
#  '0.45453027',
#  '0.45678744',
#  '0.4671458',
#  '0.48061895',
#  '0.49080437',
#  '0.4959659',
#  '0.4959353',
#  '0.49525747',
#  '0.49259216',
#  '0.5003491',
#  '0.50897753',
#  '0.50930643',
#  '0.5033618',
#  '0.4983414',
#  '0.48999137',
#  '0.47664997',
#  '0.45950496',
#  '0.43933725',
#  '0.41943595',
#  '0.39917743',
#  '0.3855318',
#  '0.4020814',
#  '0.42602685',
#  '0.45901218',
#  '0.51365364',
#  '0.558286',
#  '0.5771624',
#  '0.5741273',
#  '0.5509835',
#  '0.51752865',
#  '0.4771184',
#  '0.43503395',
#  '0.39470837',
#  '0.3605095',
#  '0.3349733',
#  '0.3170921',
#  '0.30064422',
#  '0.2882127',
#  '0.2785509',
#  '0.2646707',
#  '0.250043',
#  '0.23593107',
#  '0.21981679',
#  '0.2036948',
#  '0.1894095',
#  '0.1771771',
#  '0.16723658',
#  '0.15950333',
#  '0.15331443',
#  '0.14867531',
#  '0.1452866',
#  '0.14302124',
#  '0.14164984',
#  '0.14081092',
#  '0.14007753',
#  '0.13939758',
#  '0.13851763',
#  '0.13742289',
# ...

# %%
dfpoints
# Out:
#                                              alturas_ola longitud latitud  \
# 0      0.45341894,0.45281014,0.45453027,0.45678744,0....   -89.75   26.75
# 1      0.45341894,0.45281014,0.45453027,0.45678744,0....   -89.75   26.75
# 2      0.45341894,0.45281014,0.45453027,0.45678744,0....   -89.75   26.75
# 3      0.45341894,0.45281014,0.45453027,0.45678744,0....   -89.75   26.75
# 4      0.45341894,0.45281014,0.45453027,0.45678744,0....   -89.75   26.75
# ...                                                  ...      ...     ...
# 41785  0.21316274,0.23346135,0.24079537,0.24264361,0....   -55.25    7.25
# 41786  0.21316274,0.23346135,0.24079537,0.24264361,0....   -55.25    7.25
# 41787  0.21316274,0.23346135,0.24079537,0.24264361,0....   -55.25    7.25
# 41788  0.21316274,0.23346135,0.24079537,0.24264361,0....   -55.25    7.25
# 41789  0.21316274,0.23346135,0.24079537,0.24264361,0....   -55.25    7.25
#
#                          geometry point_id    id                fecha  \
# ...

# %%
dfpoints=pd.merge(dfj, df, left_on='point_id', right_on='id')
dfpoints['date'] = pd.to_datetime(dfpoints['fecha'], format='%Y-%m-%d %H')

# %%
db_connection_url = "postgres://postgres:postgres@172.18.152.20:5432/simar";
engine = create_engine(db_connection_url)
dfpuntos.to_postgis(name="grilla_caribe", con=engine)

# %%
df_oleaje = dfpoints.iloc[:,[5,8,7,3]]
df_oleaje.to_csv('oleajeFull.csv')

# %%
df_oleaje = df_oleaje.set_geometry('geometry')
df_oleaje['date'] = df_oleaje['date'].astype('str')

# %%
oleaje = shapely.geometry.mapping(df_oleaje)
with open('oleaje.geojson','w') as file:
    json.dump(oleaje, file)

# %%
df_oleaje_d1= df_oleaje[df_oleaje['date']=='2020-09-10 12:00:00']
df_oleaje_d1.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 8358 entries, 0 to 41785
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          8358 non-null   object
#  1   date        8358 non-null   object
#  2   altura_ola  8358 non-null   float64
#  3   geometry    8358 non-null   geometry
# dtypes: float64(1), geometry(1), object(2)
# memory usage: 326.5+ KB

# %%
x = list(df_oleaje_d1.geometry[:6].x)
y = list(df_oleaje_d1.geometry[:6].y)
z = list(df_oleaje_d1.altura_ola[:6])
# Out:
# [-89.75, -89.5, -89.25, -89.0, -88.75, -88.5]
# [26.75, 26.75, 26.75, 26.75, 26.75, 26.75]
# [0.46782971375000004, 0.45525802958333333, 0.44588170749999995, 0.43342466249999995, 0.40650675333333336, 0.37396686125]

# %%
import plotly.graph_objects as go

fig = go.Figure (data = [go.Surface (z = df_oleaje_d1.altura_ola)])
fig.update_layout (title = 'Volcano', autosize = False, 
                  width = 500, height = 500, 
                  margin = dict (l = 65, r = 50, b = 65, t = 90))
fig.show ()
# Out:
# <div>                            <div id="93dec3f8-8590-433b-bcd9-028427d85030" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93dec3f8-8590-433b-bcd9-028427d85030")) {                    Plotly.newPlot(                        "93dec3f8-8590-433b-bcd9-028427d85030",                        [{"type": "surface", "z": [0.46782971375000004, 0.45525802958333333, 0.44588170749999995, 0.43342466249999995, 0.40650675333333336, 0.37396686125, 0.33981295166666675, 0.30974058708333335, 0.28201330583333334, 0.25683343708333334, 0.23589557458333335, 0.2199948416666667, 0.20743182916666666, 0.19994535333333333, 0.19625945625, 0.18984744500000006, 0.18639443041666667, 0.18951299749999995, 0.19170407708333337, 0.18932731583333332, 0.15281143345833328, 0.1602015524
# ...

# %%
import xarray as xr
import plotly.offline as py_off
from plotly.graph_objs import *
import numpy as np
import plotly as py
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

# %%
token = 'pk.eyJ1IjoiYW1vbnRveWFnbyIsImEiOiJja2hxemZrbHIwNHFwMnJveTZ0YzhwbDAwIn0.R6vWzMqVL06H7nyBMruqjA'

colorscale = [[0, 'rgb(54, 50, 153)'], [0.35, 'rgb(17, 123, 215)'],
                [0.5, 'rgb(37, 180, 167)'], [0.6, 'rgb(134, 191, 118)'],
                [0.7, 'rgb(249, 210, 41)'], [1.0, 'rgb(244, 236, 21)']]

data = []
data.append(
    Scattermapbox(
        lon=df_oleaje.geometry[:].x,
        lat=df_oleaje.geometry[:].y,
        mode='markers',
        text=df_oleaje['altura_ola'].values,
        marker=Marker(
            cmax=2.5,
            cmin=-2.5,
            color=df_oleaje['altura_ola'].values,
            colorscale=colorscale
        ),
    )
)
        
layout = Layout(
    margin=dict(t=0,b=0,r=0,l=0),
    autosize=True,
    hovermode='closest',
    showlegend=False,
    mapbox=dict(
        accesstoken=token,
        bearing=0,
        center=dict(
            lat=38,
            lon=-94
        ),
        pitch=0,
        zoom=0,
        style='dark'
    ),
)

app = dash.Dash(__name__, external_stylesheets=['https://codepen.io/uditagarwal/pen/oNvwKNP.css'])

app.layout = html.Div([
    dcc.Graph(id='date-picker-range'),
    dcc.Slider(
        id='date-picker-range',
        min=df_oleaje['date'].min(),
        max=df_oleaje['date'].max(),
        value=df_oleaje['date'].min(),
        marks={str(date): str(date) for date in df_oleaje['date'].unique()},
        step=None
    )
])

fig = dict(data=data, layout=layout)

@app.callback(
   dash.dependencies.Output('map-plot', 'figure'), # El componente con el id map-plot se cambiara, el arcumento 'figure' es actualizado
    [
        dash.dependencies.Input('date-picker-range', 'start_date'), # input con el id date-picker-range y el parametro start_date
        dash.dependencies.Input('date-picker-range', 'end_date')
    ])

def update_figure(selected_day):
    filtered_df = df_oleaje[df_oleaje.date == selected_day]

    fig = px.scatter(filtered_df, x="lon", y="lat",
                     size="pop", color=colorscale, hover_name="altura_ola",
                     log_x=True, size_max=55)

    fig.update_layout(transition_duration=500)

    return fig

py.offline.plot(fig, filename='oleaje.html', auto_open=False)
# Out:
# /home/geo/miniconda3/envs/TEST/lib/python3.7/site-packages/plotly/graph_objs/_deprecations.py:441: DeprecationWarning:
#
# plotly.graph_objs.Marker is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Marker
#   - plotly.graph_objs.histogram.selected.Marker
#   - etc.
# ---------------------------------------------------------------------------
# NonExistentIdException                    Traceback (most recent call last)
# <ipython-input-38-10e155be697e> in <module>()
#      59     [
#      60         dash.dependencies.Input('date-picker-range', 'start_date'), # input con el id date-picker-range y el parametro start_date
# ---> 61         dash.dependencies.Input('date-picker-range', 'end_date')
#      62     ])
#      63
#
# /home/geo/miniconda3/envs/TEST/lib/python3.7/site-packages/dash/dash.py in callback(self, output, inputs, state)
#    1150     # pylint: disable=dangerous-default-value
# ...

# %%
dfoleaje = pd.read_csv('oleajeFull.csv',parse_dates=['date'])
dfoleaje = dfoleaje.set_geometry('geometry')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f38463f516a2> in <module>()
#       1 dfoleaje = pd.read_csv('oleajeFull.csv',parse_dates=['date'])
# ----> 2 dfoleaje = dfoleaje.set_geometry('geometry')
#
# /home/geo/miniconda3/envs/TEST/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5134             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5135                 return self[name]
# -> 5136             return object.__getattribute__(self, name)
#    5137
#    5138     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'set_geometry'

# %%
dfoleaje
# Out:
#        Unnamed: 0    id                date  altura_ola              geometry
# 0               0     0 2020-09-10 12:00:00    0.467830  POINT (-89.75 26.75)
# 1               1     0 2020-09-11 12:00:00    0.368623  POINT (-89.75 26.75)
# 2               2     0 2020-09-12 12:00:00    0.162197  POINT (-89.75 26.75)
# 3               3     0 2020-09-13 12:00:00    0.236514  POINT (-89.75 26.75)
# 4               4     0 2020-09-14 12:00:00    0.141853  POINT (-89.75 26.75)
# ...           ...   ...                 ...         ...                   ...
# 41785       41785  8357 2020-09-10 12:00:00    0.353733   POINT (-55.25 7.25)
# 41786       41786  8357 2020-09-11 12:00:00    0.503938   POINT (-55.25 7.25)
# 41787       41787  8357 2020-09-12 12:00:00    0.552705   POINT (-55.25 7.25)
# 41788       41788  8357 2020-09-13 12:00:00    0.598688   POINT (-55.25 7.25)
# 41789       41789  8357 2020-09-14 12:00:00    0.665789   POINT (-55.25 7.25)
#
# [41790 rows x 5 columns]
